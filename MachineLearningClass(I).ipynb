# %% [markdown]
# #JEPG IMAGE HANDLING AND LOADING

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('D:\\My Files\\143859432_862313247892211_5979315367643606923_n.jpg')
plt.imshow(img)
plt.show() #Load Image RGB
print(img.shape)
# Out:
# (1440, 1440, 3)

# %%
img[:,:,0] #We sliced all R values (R means Red)
img[:,:,1] #We sliced all  values (G means Green)
img[:,:,2] #We sliced all B values (B means Blue)
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
#Reading PNG image format
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img1 = mpimg.imread('D:\\My Files\\GitHub-Mark.png', format = 'png')
plt.imshow(img1)
plt.show() #Load Image RGB
print(img1.shape)
# Out:
# (560, 560, 4)

# %%
from PIL import Image # Open Image with operating system
imgpil = Image.open('D:\\My Files\\GitHub-Mark.png')
imgpil.show()

# %%
#WorkingWithCV
#installation Command

import cv2
# By default we have GBR mode (Green Blue and Red)
img2 = cv2.imread('D:\\My Files\\143859432_862313247892211_5979315367643606923_n.jpg')
plt.imshow(img2)

# %%
import cv2
img2 = cv2.imread('D:\\My Files\\143859432_862313247892211_5979315367643606923_n.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
# HANDLING DATA FROM TENSORFLOW FROM ANY FOLDER DIRECTORY FOR TRANING PURPOSE

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_dataGen = ImageDataGenerator(rescale = 1.0/255)
training_directory = 'C:\\Users\\Muhammad Sameer\\Desktop\\Animals'

# Now we will load or train or generate numpy array from folder

train_generator = training_dataGen.flow_from_directory(
    training_directory,
    target_size = (150,150),
    batch_size = 16,
    class_mode = 'binary',
    
)
# Out:
# Found 4 images belonging to 2 classes.

# %%
#LOADING AND DISPLAY IMAGE BY TENSORFLOW
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
img = image.load_img('D:\\My Files\\278190453_1131608487629351_1278978382136414550_n.jpg', target_size = (150,150), color_mode="rgb")
img_array = image.img_to_array(img)
print(img_array.shape)
plt.imshow(img_array/255)
# Out:
# (150, 150, 3)

# %%
#Load Image with Numpy
from PIL import Image
import numpy as np

img4 = np.array(Image.open('D:\\My Files\\GitHub-Mark.png').convert("RGB"))
plt.imshow(img4)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
img2 = cv2.imread('D:\\My Files\\143859432_862313247892211_5979315367643606923_n.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img2, cmap = plt.get_cmap('gray'))
plt.show()

# %%
#Working With Audio Data

from scipy.io import wavfile 
rate1, dat1 = wavfile.read('C:\\Users\\Muhammad Sameer\\Desktop\Animals\\Over the horizon.wav')
print(rate1)
print(dat1)
# Out:
# 44100
# [[   0    0]
#  [   0    0]
#  [   0    0]
#  ...
#  [1067 -220]
#  [2033   -5]
#  [1947  -52]]

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys 
import wave

spf = wave.open('C:\\Users\\Muhammad Sameer\\Desktop\Animals\\Over the horizon.wav', "r")
#Extract Raw Audio from Wave File
signal = spf.readframes(-1)
signal = np.fromstring(signal, np.int16)

plt.figure(1)
plt.title("Signal Wave")
plt.plot(signal)
plt.show()
# Out:
# C:\Users\Muhammad Sameer\AppData\Local\Temp\ipykernel_14132\2245573370.py:9: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   signal = np.fromstring(signal, np.int16)

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys 
import wave

spf = wave.open('C:\\Users\\Muhammad Sameer\\Desktop\Animals\\Over the horizon.wav', "r")
#Extract Raw Audio from Wave File
signal = spf.readframes(-1)
signal = np.fromstring(dat1, np.int16)

plt.figure(1)
plt.title("Signal Wave")
plt.plot(dat1)
plt.show()
# Out:
# C:\Users\Muhammad Sameer\AppData\Local\Temp\ipykernel_14132\3789680073.py:9: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   signal = np.fromstring(dat1, np.int16)

# %%
#WORKING ON VIDEO 
# import numpy as np 
# import cv2

# cap = cv2.VideoCapture(0)

# while(True):
#     ret, frame = cap.read()
#     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    
#     cv2.imshow('frame', gray)
#     if cv2.waitKey(1) & 0xFF == ord('q'):
#         break 
        
# cap.release()
# cv2.destroyAllWindows()
