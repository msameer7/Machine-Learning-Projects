# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'C:\Users\SAMIA DAWOOD\OneDrive\Desktop\application_record.csv')

# %%
dataset
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
dataset.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
dataset['CODE_GENDER'].replace({'M':'0','F':'1'},inplace=True)

# %%
dataset
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           0            Y               Y             0
# 1       5008805           0            Y               Y             0
# 2       5008806           0            Y               Y             0
# 3       5008808           1            N               Y             0
# 4       5008809           1            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           0            N               Y             0
# 438553  6840222           1            N               N             0
# 438554  6841878           1            N               N             0
# 438555  6842765           1            N               Y             0
# 438556  6842885           1            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
plt.scatter(x='ID',y='CODE_GENDER', data=dataset)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dataset[['ID']],dataset['CODE_GENDER'],test_size=0.2)

# %%
x_train
# Out:
#              ID
# 369074  6542491
# 130989  5617599
# 37880   6152622
# 200307  5898879
# 68619   5243501
# ...         ...
# 200998  5905298
# 66177   5236657
# 339048  6395073
# 162355  5761457
# 318793  6263560
#
# [350845 rows x 1 columns]

# %%
y_train
# Out:
# 369074    0
# 130989    1
# 37880     1
# 200307    1
# 68619     1
#          ..
# 200998    0
# 66177     1
# 339048    1
# 162355    0
# 318793    1
# Name: CODE_GENDER, Length: 350845, dtype: object

# %%
x_test
# Out:
#              ID
# 77854   5632919
# 321758  6543525
# 297052  6172936
# 27788   6605373
# 137667  5637187
# ...         ...
# 6975    5026491
# 102736  5427288
# 35655   5753662
# 189072  5868511
# 123919  6603608
#
# [87712 rows x 1 columns]

# %%
y_test
# Out:
# 77854     1
# 321758    1
# 297052    1
# 27788     1
# 137667    0
#          ..
# 6975      1
# 102736    1
# 35655     1
# 189072    0
# 123919    1
# Name: CODE_GENDER, Length: 87712, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['1', '1', '1', ..., '1', '1', '1'], dtype=object)

# %%
lr.predict([[2222]])
# Out:
# C:\Users\SAMIA DAWOOD\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['1'], dtype=object)

# %%
import pandas as pd

# %%
dataset=pd.read_csv(r'C:\Users\SAMIA DAWOOD\OneDrive\Desktop\IRIS.csv')

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
dataset['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
dataset['species'].replace({'Iris-setosa':'1', 'Iris-versicolor':'2', 'Iris-virginica':'3'},inplace=True)

# %%
dataset
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       3
# 146           6.3          2.5           5.0          1.9       3
# 147           6.5          3.0           5.2          2.0       3
# 148           6.2          3.4           5.4          2.3       3
# 149           5.9          3.0           5.1          1.8       3
#
# [150 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(dataset[['sepal_length','sepal_width','petal_length','petal_width',]],dataset['species'],test_size=0.2)

# %%
x_train
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 22            4.6          3.6           1.0          0.2
# 86            6.7          3.1           4.7          1.5
# 37            4.9          3.1           1.5          0.1
# 122           7.7          2.8           6.7          2.0
# 95            5.7          3.0           4.2          1.2
# ..            ...          ...           ...          ...
# 89            5.5          2.5           4.0          1.3
# 20            5.4          3.4           1.7          0.2
# 112           6.8          3.0           5.5          2.1
# 43            5.0          3.5           1.6          0.6
# 81            5.5          2.4           3.7          1.0
#
# [120 rows x 4 columns]

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 46            5.1          3.8           1.6          0.2
# 147           6.5          3.0           5.2          2.0
# 49            5.0          3.3           1.4          0.2
# 116           6.5          3.0           5.5          1.8
# 132           6.4          2.8           5.6          2.2
# 41            4.5          2.3           1.3          0.3
# 21            5.1          3.7           1.5          0.4
# 23            5.1          3.3           1.7          0.5
# 5             5.4          3.9           1.7          0.4
# 83            6.0          2.7           5.1          1.6
# 142           5.8          2.7           5.1          1.9
# 90            5.5          2.6           4.4          1.2
# 84            5.4          3.0           4.5          1.5
# 149           5.9          3.0           5.1          1.8
# 33            5.5          4.2           1.4          0.2
# ...

# %%
y_train
# Out:
# 22     1
# 86     2
# 37     1
# 122    3
# 95     2
#       ..
# 89     2
# 20     1
# 112    3
# 43     1
# 81     2
# Name: species, Length: 120, dtype: object

# %%
y_test
# Out:
# 46     1
# 147    3
# 49     1
# 116    3
# 132    3
# 41     1
# 21     1
# 23     1
# 5      1
# 83     2
# 142    3
# 90     2
# 84     2
# 149    3
# 33     1
# 139    3
# 91     2
# 136    3
# 19     1
# 54     2
# 72     2
# 40     1
# 24     1
# 77     2
# 85     2
# 65     2
# 47     1
# 140    3
# 50     2
# 68     2
# Name: species, dtype: object

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\SAMIA DAWOOD\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array(['1', '3', '1', '3', '3', '1', '1', '1', '1', '3', '3', '2', '2',
#        '3', '1', '3', '2', '3', '1', '2', '3', '1', '1', '3', '2', '2',
#        '1', '3', '2', '2'], dtype=object)

# %%
x_test
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 46            5.1          3.8           1.6          0.2
# 147           6.5          3.0           5.2          2.0
# 49            5.0          3.3           1.4          0.2
# 116           6.5          3.0           5.5          1.8
# 132           6.4          2.8           5.6          2.2
# 41            4.5          2.3           1.3          0.3
# 21            5.1          3.7           1.5          0.4
# 23            5.1          3.3           1.7          0.5
# 5             5.4          3.9           1.7          0.4
# 83            6.0          2.7           5.1          1.6
# 142           5.8          2.7           5.1          1.9
# 90            5.5          2.6           4.4          1.2
# 84            5.4          3.0           4.5          1.5
# 149           5.9          3.0           5.1          1.8
# 33            5.5          4.2           1.4          0.2
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.9

# %%
import seaborn as sns

# %%
sns.pairplot(dataset[['sepal_length','sepal_width','petal_length','petal_width','species']],hue='species')
